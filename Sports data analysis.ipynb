# %%
import pandas as pd
from google.colab import files
uploaded=files.upload

# %%
data=pd.read_csv('/content/batting_stats_T20I.csv')

# %%
data
# Out:
#       Batter id             Batter         Country  No. of Innings  \
# 0             0         A Ahmadhel        Bulgaria               3
# 1             1            A Amado          Israel               2
# 2             2          A Andrews     Switzerland               1
# 3             3          A Ashokan  Czech Republic              21
# 4             4            A Bagai          Canada               4
# ...         ...                ...             ...             ...
# 2894       2894      Zohaib Sarwar        Portugal               9
# 2895       2895       Zong Yuechao           China               1
# 2896       2896   Zubaidi Zulkifle        Malaysia              28
# 2897       2897     Zulfiqar Babar        Pakistan               3
# 2898       2898  Zulqarnain Haider  Pakistan/Spain               5
#
#       No. of Not Outs  Total Runs  Total Balls Faced  No. of Outs  \
# 0                   0           6                 18            3
# ...

# %%
import plotly.graph_objects as go
import pandas as pd
df = pd.DataFrame(data)
fig = go.Figure()
fig.add_trace(go.Scatter(x=df['Strike Rate']))
fig.update_layout(title='Team Performance Over Seasons',
                 xaxis_title='Batter id',
                 yaxis_title='Strike rate',
                 font=dict(size=14))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
