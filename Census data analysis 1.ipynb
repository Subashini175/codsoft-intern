# %%
import pandas as pd
from google.colab import files
uploaded=files.upload

# %%
data=pd.read_csv('/content/Adult Data.csv')

# %%
data
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13   Married-civ-spouse
# 1      38            Private  215646        HS-grad    9             Divorced
# 2      53            Private  234721           11th    7   Married-civ-spouse
# 3      28            Private  338409      Bachelors   13   Married-civ-spouse
# 4      37            Private  284582        Masters   14   Married-civ-spouse
# ...    ..                ...     ...            ...  ...                  ...
# 17183  23            Private  529223      Bachelors   13        Never-married
# 17184  22            Private  202871      Assoc-voc   11   Married-civ-spouse
# 17185  37            Private   58337   Some-college   10             Divorced
# 17186  58        Federal-gov  298643        HS-grad    9             Divorced
# 17187  61            Private  191188           10th    6              Widowed
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 17183               Sales       Own-child   Black     Male      0   0   10
# 17184       Other-service         Husband   White     Male      0   0   44
# 17185     Exec-managerial   Not-in-family   White   Female      0   0   40
# 17186        Adm-clerical       Unmarried   Black   Female      0   0   40
# 17187     Farming-fishing       Unmarried   White     Male      0   0   20
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 17183   United-States   <=50K
# 17184   United-States   <=50K
# 17185   United-States    >50K
# 17186   United-States   <=50K
# 17187      United-Sta     NaN
#
# [17188 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.histplot(data=data, x='39', bins=30, kde=True)
plt.title('Distribution of Age')
plt.show()
